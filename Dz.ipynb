# %%
# !pip install matplotlib


x = 5
y = 4
x + y
# Out:
# Requirement already satisfied: matplotlib in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\siare\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: C:\Users\siare\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# 9

# %%
from matplotlib import pyplot as plt

x = [1, 2]

plt.plot(x)

# %%
x=[x+0.5 for x in range(-100, 100)]
y=[1/t for t in x]
plt.plot(x,y)

# %%
from matplotlib import pyplot as plt
import math

def f(x):
    return math.sin(x)

x = [x/100 for x in range (-1000, 1000)]
y = [f(t)for t in x]
# y = [math.sin(t) for t in x]
plt.plot(x,y)

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ---------------------------------------- 6.5/6.5 MB 8.3 MB/s eta 0:00:00
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      ------------------------------------- 532.6/532.6 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.2.1 sympy-1.11.1
#   WARNING: The script isympy.exe is installed in 'C:\Users\siare\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: C:\Users\siare\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sympy import *
from sympy.plotting import plot as symp

# %%
x = symbols('x')
p2 = plot(5*x, show = false)
p1 = plot(-12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30, show = false)
# p1.append(p2[0])
p1.show()
# f(x) = -12*x**4*sin(cos(x)) - 18x**3+5*x**2 + 10x - 30

# %%
import  numpy as np

# %%
a, b, c, d, e = -12, -18, 5, 10, -30


def func(x):
    return a * x ** 4 * np.sin(np.cos(x)) + b * x ** 3 + c * x ** 2 + d * x + e


limit = 10
step = 0.0001
x = np.arange(-limit, limit, step)
plt.plot(x, func(x), step)
plt.grid()
plt.show()

# %%
limit = 3
step = 0.00001
x = np.arange(-limit, limit, step)

min_y = min(func(x))

# %%
x_down = np.arange(-limit, -1.33895 + step, step)
x_down_m_zero = np.arange(-1.33896, -0.394 + step, step)
x_up_zero = np.arange(-0.394, 0.45510 + step, step)
x_down_p_zero = np.arange(0.45510, 1.7006 + step, step)
x_up_p_zero = np.arange(1.7006,  2.27 + step, step)
x_up = np.arange(2.27, limit  + step, step)

# %%
plt.rcParams['lines.linestyle'] = '-'
plt.plot(x_down, func(x_down), 'r', label='Уменьшение до нуля')
plt.plot(x_up, func(x_up), 'b', label='Возрастание больше нуля')

plt.rcParams['lines.linestyle'] = '-.'
plt.plot(x_down_m_zero, func(x_down_m_zero), 'r', label='Уменьшение меньше нуля')
plt.plot(x_up_zero, func(x_up_zero), 'b', label='Возрастание меньше нуля')
plt.plot(x_down_p_zero, func(x_down_p_zero), 'r')
plt.plot(x_up_p_zero, func(x_up_p_zero), 'b')

plt.plot(-1.3389666389, 0, 'yo', label=f'Корни (-1.33896, 2.27305)')
plt.plot(2.2730568449, 0, 'yo')
plt.plot(1.700608610, min_y, 'gx', label=f'Экстремум функции (1.700608610, {min_y})')
plt.legend()
plt.grid()
plt.show()
plt.rcParams['lines.linestyle'] = '-'
